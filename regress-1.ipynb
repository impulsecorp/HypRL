# %%
from hyperl import *

# %%
learn_model()
# Out:
# 7000 steps, 0.4688 / 0.4809, best: 0.6250 / 0.4976
# best ever: 0.8438 / 0.7608
# Accuracy scores: 0.4688 / 0.4809
# Action: Attempt to remove node at caret position
# Reward: 0.46875, charge for n/l: 1.0000/1.0000
# Caret row/col: 8/11
